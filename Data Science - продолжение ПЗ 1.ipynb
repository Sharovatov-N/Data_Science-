# %% [markdown]
# # Библиотеки Python для Data Science: продолжение

# %% [markdown]
# ## Практическое задание к уроку №1.

# %% [markdown]
# ### 1. Приведите по 2 примера, когда лучше максимизировать Precision, а когда Recall.

# %% [markdown]
# #### Выявление спама:
# Для фильтрации спама лучше максимизировать Precision (лучше пропустить некоторое количество спама чем ошибочно классифицировать порядочное письмо как спам)
# #### Фруктовый сад, прогнозиравание нашествие вредителей (использовать ядо-химикаты или нет):
# Если стоит задача минимизировать использование ядо-химикатов, сохранение сада в долгосрочной перспективе, защита экологии то лучше максимизировать Precision.<br>
# Если стоит задача "урожай любой ценой" то лучше максимизировать Racall.
# #### Медецинская диагностика:
# При медицинском тестировании false negative будет давать ложно обнадеживающее сообщение пациентам и врачам о том, что болезнь отсутствует, когда в действительности она присутствует. Это иногда приводит к неуместному или неадекватному лечению. Таким образом, в этом случае лучше максимизировать Recall.

# %% [markdown]
# ### 2. Почему мы используем F-меру, почему, например, нельзя просто взять среднее от Precision и Recall?

# %% [markdown]
# F-мера представляет собой гармоническое среднее между Precision и Recall. Гармоническое среднее, в отличии арифметического стремится к нулю когда хотя бы одно из значений стремится к нулю, т.е. она стремится к нулю, если Precision или Recall стремится к нулю. Это хорошо можно представить на графиках.
# <h4>Для среднего арифметического <img src="mean.jpg">
# <h4>Для F-score <img src="F.jpg">
